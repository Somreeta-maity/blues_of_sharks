# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('C:/Users/maity/OneDrive/Desktop/Pworld/matplotlib/mEdico_scm_Myst.csv')
data.sample(5)
# Out:
#      episode_number  pitch_number  brand_name  \
# 64               21            65  Get a Whey
# 48               16            49   Let's Try
# 109              33           110      Proxgy
# 19                7            20    Torch-it
# 99               31           100  Sabjikothi
#
#                                      idea  deal  pitcher_ask_amount  \
# 64                    Sugar-Free Icecream     1               100.0
# 48                         Healthy Snacks     1                45.0
# 109                                    VR     1                35.0
# 19   Gadgets for visually impaired people     1                75.0
# 99                     Vegetables Storage     0                60.0
#
#      ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 64          8.0         1250.0        100.0         15.0  ...             1
# 48          2.0         2250.0         45.0         12.0  ...             0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   episode_number         117 non-null    int64
#  1   pitch_number           117 non-null    int64
#  2   brand_name             117 non-null    object
#  3   idea                   117 non-null    object
#  4   deal                   117 non-null    int64
#  5   pitcher_ask_amount     117 non-null    float64
#  6   ask_equity             117 non-null    float64
#  7   ask_valuation          117 non-null    float64
#  8   deal_amount            117 non-null    float64
#  9   deal_equity            117 non-null    float64
#  10  deal_valuation         117 non-null    float64
#  11  ashneer_present        117 non-null    int64
#  12  anupam_present         117 non-null    int64
#  13  aman_present           117 non-null    int64
# ...

# %%
data.describe()
# Out:
#        episode_number  pitch_number        deal  pitcher_ask_amount  \
# count      117.000000    117.000000  117.000000          117.000000
# mean        18.735043     59.000000    0.555556          319.854709
# std         10.070778     33.919021    0.499041         2767.842777
# min          1.000000      1.000000    0.000000            0.001010
# 25%         10.000000     30.000000    0.000000           45.000000
# 50%         19.000000     59.000000    1.000000           50.000000
# 75%         27.000000     88.000000    1.000000           80.000000
# max         35.000000    117.000000    1.000000        30000.000000
#
#        ask_equity  ask_valuation  deal_amount  deal_equity  deal_valuation  \
# count  117.000000     117.000000   117.000000   117.000000      117.000000
# mean     5.188034    3852.462479    31.982915     8.963504      467.104872
# std      3.892121   11931.601957    36.687391    13.106769      919.988864
# ...

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
data['deal'].value_counts().plot(kind= 'pie', autopct='%.2f%%')
plt.subplot(1,2,2)
sns.countplot(x = 'deal', data=data)
plt.show()

# %%
sns.boxplot(x = 'pitcher_ask_amount', data = data)
# Out:
# <AxesSubplot:xlabel='pitcher_ask_amount'>

# %%
data[data['pitcher_ask_amount']==30000].T.iloc[:10,:]
# Out:
#                                  30
# episode_number                   11
# pitch_number                     31
# brand_name               Gopal's 56
# idea                Fiber Ice Cream
# deal                              0
# pitcher_ask_amount          30000.0
# ask_equity                     25.0
# ask_valuation              120000.0
# deal_amount                     0.0
# deal_equity                     0.0

# %%
plt.figure(figsize = (20,5))
plt.subplot(1,3,1)
sns.histplot(x='pitcher_ask_amount', data=data.drop(data[data['pitcher_ask_amount']==30000].index,axis=0),kde=True)
plt.subplot(1,3,2)
sns.histplot(x = 'ask_equity', data=data, kde=True)
plt.subplot(1,3,3)
sns.histplot(x = 'ask_valuation', data = data.drop(data[data['pitcher_ask_amount'] == 30000].index, axis = 0), kde = True)
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.subplot(1,3,1)
sns.kdeplot(x='pitcher_ask_amount', data =  data.drop(data[data['pitcher_ask_amount']==30000].index,axis=0), hue = 'deal', shade=True)
plt.subplot(1,3,2)
sns.kdeplot(x='ask_equity', data=data, hue='deal', shade= True)
plt.subplot(1,3,3)
sns.kdeplot(x='ask_valuation',data=data.drop(data[data['pitcher_ask_amount']==30000].index, axis = 0), hue = 'deal', shade =True)
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.subplot(1,3,1)
sns.histplot(x = 'deal_amount', data = data[data['deal']==1], kde = True)
plt.subplot(1,3,2)
sns.histplot(x = 'deal_equity', data = data[data['deal']==1], kde = True)
plt.show()

# %%
plt.figure(figsize = (13,5))
plt.subplot(1,2,1)
data['total_sharks_invested'].value_counts().plot(kind='pie' , autopct = '%.2f%%')
plt.subplot(1,2,2)
sns.countplot(x = 'total_sharks_invested', data=data)
plt.show()

# %%
#Total attendance of each shark.

#Anupam was present 100% of the time.
#lowest is Vineeta with only 56.41%

# %%
plt.figure(figsize = (25,5))
for i , col in enumerate(['ashneer_present', 'anupam_present',
       'aman_present', 'namita_present', 'vineeta_present', 'peyush_present',
       'ghazal_present']):
    plt.subplot(1,7,i+1)
    data[col].value_counts().plot(kind='pie', autopct = '%.2f%%')
plt.show()

# %%
plt.figure(figsize = (20,10))
for i , col in enumerate([ 'ashneer', 'anupam', 'aman',
       'namita', 'vineeta', 'peyush', 'ghazal']):
    plt.subplot(3,4,i+1)
    sns.countplot(data = data[data[col+'_present'] == 1], x = col+'_deal')
    plt.ylim((0,100))
plt.show()

# %%
plt.figure(figsize = (15,4))
plt.subplot(1,2,1)
sns.boxplot(x = 'amount_per_shark', data = data[data['deal'] == 1])
plt.subplot(1,2,2)
sns.boxplot(x = 'equity_per_shark', data = data[data['deal'] == 1])
plt.show()

# %%
data[data['equity_per_shark'].isin([40,50,75])].loc[:,['episode_number', 'pitch_number', 'brand_name', 'idea', 'deal',
       'pitcher_ask_amount', 'ask_equity', 'ask_valuation', 'deal_amount',
       'deal_equity', 'deal_valuation', 'ashneer_deal', 'anupam_deal', 'aman_deal',
       'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal',
       'total_sharks_invested', 'amount_per_shark', 'equity_per_shark']].T
# Out:
#                                          42             65  \
# episode_number                           15             21
# pitch_number                             43             66
# brand_name                 Hammer Lifestyle  Sid07 Designs
# idea                   Smart Audio Products     Inventions
# deal                                      1              1
# pitcher_ask_amount                     30.0           47.0
# ask_equity                              3.0           10.0
# ask_valuation                        1000.0          470.0
# deal_amount                           100.0           25.0
# deal_equity                            40.0           75.0
# deal_valuation                        250.0          33.33
# ashneer_deal                              0              0
# anupam_deal                               0              0
# aman_deal                                 1              0
# namita_deal                               0              0
# ...

# %%
win = data[data['deal']==1]

# %%
plt.figure(figsize = (25,5))
sns.barplot(x = win['pitch_number'], y = win['deal_valuation'] - win['ask_valuation'])
plt.show()

# %%
plt.figure(figsize = (25,5))
sns.barplot(x = win['pitch_number'], y = win['deal_equity'] - win['ask_equity'])
plt.show()

# %%
total_amount_per_shark = {}
for col in  ['ashneer_deal', 'anupam_deal', 'aman_deal',
       'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal']:
     total_amount_per_shark[col] = [np.sum(win[win[col] == 1].loc[:,'amount_per_shark'])]

total_equity_per_shark = {}
for col in [ 'ashneer_deal', 'anupam_deal', 'aman_deal',
       'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal']:
    total_equity_per_shark[col] = [np.sum(win[win[col] == 1].loc[:,'equity_per_shark'])]
    
plt.figure(figsize = (15,4))
plt.subplot(1,2,1)
sns.barplot(x = 'index',y = 'Total Amount' ,data =  pd.DataFrame(total_amount_per_shark).T.reset_index().rename(columns = {0:'Total Amount'}))
plt.xticks(rotation = 90)
plt.subplot(1,2,2)
sns.barplot(x = 'index',y = 'Total Equity' ,data =  pd.DataFrame(total_equity_per_shark).T.reset_index().rename(columns = {0:'Total Equity'}))
plt.xticks(rotation = 90)
plt.show()

# %%
deal_by_episodes = data.groupby(by = 'episode_number').sum()[['deal','deal_amount','ashneer_deal', 'anupam_deal', 'aman_deal',
                                                              'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal']].reset_index()

# %%
plt.figure(figsize = (15,5))
sns.lineplot(x = 'episode_number', y = 'deal', data = deal_by_episodes)
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.lineplot(x = 'episode_number', y = 'deal_amount', data = deal_by_episodes)
plt.show()

# %%
plt.figure(figsize = (15,13))
sns.heatmap(data = deal_by_episodes.drop(['deal_amount','deal'], axis = 1).set_index('episode_number'), vmin = 0, cmap = 'Blues', annot = True)
plt.show()

# %%
sharks = ['ashneer_deal', 'anupam_deal', 'aman_deal',
       'namita_deal', 'vineeta_deal', 'peyush_deal', 'ghazal_deal']
mat = []
for i in range(len(sharks)):
    temp = []
    for j in range(len(sharks)):
        x = sharks[i]
        y = sharks[j]
        temp.append((win.query(f"{x} == 1 and {y} == 1").shape[0]/win.query(f"{x} == 1 or {y} == 1").shape[0])*100)
    mat.append(temp)
    
shark_df = pd.DataFrame(mat, columns = sharks, index = sharks)

plt.figure(figsize = (12,10))
sns.heatmap(data = shark_df,vmin = 0, vmax = 100, cmap = 'Blues', annot = True, fmt = 'g')
plt.show()
